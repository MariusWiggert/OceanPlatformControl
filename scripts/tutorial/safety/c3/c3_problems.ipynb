# %%
import xarray as xr
import datetime 
import numpy as np

# %%
ds = xr.load_dataset("data/c3_problems/GLBy0_expt_93_stride_1.nc4")
#ds = xr.load_dataset("/home/andy/code/OceanPlatformControl/data/tests/test_GarbagePatchSource/ssh_ts3z_uv3z_ALL-DATA-YEARS-2022-10-08T00:00:00Z-2022-10-08T23:00:00Z.nc")

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 8, depth: 1, lat: 976, lon: 201)
# Coordinates:
#   * time     (time) datetime64[ns] 2022-04-13 ... 2022-04-13T21:00:00
#   * depth    (depth) float64 4.0
#   * lat      (lat) float64 -33.0 -32.96 -32.92 -32.88 ... 5.88 5.92 5.96 6.0
#   * lon      (lon) float64 0.0 0.07996 0.16 0.24 ... 15.76 15.84 15.92 16.0
# Data variables:
#     water_u  (time, depth, lat, lon) float32 -0.142 -0.152 -0.155 ... nan nan
#     water_v  (time, depth, lat, lon) float32 0.104 0.092 0.064 ... nan nan nan
# Attributes: (12/15)
#     classification_level:      UNCLASSIFIED
#     distribution_statement:    Approved for public release. Distribution unli...
#     downgrade_date:            not applicable
#     classification_authority:  not applicable
#     institution:               Fleet Numerical Meteorology and Oceanography C...
#     source:                    HYCOM archive file
#     ...                        ...
# ...

# %%
ds_2 = xr.load_dataset("data/miss_gen_hindcast/ssh_ts3z_uv3z_ALL-DATA-YEARS-2022-08-21T00:00:00Z-2022-08-21T23:00:00Z.nc")
ds_2 = xr.load_dataset("data/c3_problems/GLBy0_expt_93(1)_region_1.nc4")
ds_2
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 8, depth: 1, lat: 626, lon: 688)
# Coordinates:
#   * time     (time) datetime64[ns] 2022-10-08 ... 2022-10-08T21:00:00
#   * depth    (depth) float64 4.0
#   * lat      (lat) float64 15.0 15.04 15.08 15.12 ... 39.88 39.92 39.96 40.0
#   * lon      (lon) float64 200.0 200.1 200.2 200.2 ... 254.7 254.8 254.9 255.0
# Data variables:
#     water_u  (time, depth, lat, lon) float32 -0.087 -0.1 -0.108 ... nan nan nan
#     water_v  (time, depth, lat, lon) float32 0.082 0.097 0.105 ... nan nan nan
# Attributes: (12/15)
#     classification_level:      UNCLASSIFIED
#     distribution_statement:    Approved for public release. Distribution unli...
#     downgrade_date:            not applicable
#     classification_authority:  not applicable
#     institution:               Fleet Numerical Meteorology and Oceanography C...
#     source:                    HYCOM archive file
#     ...                        ...
# ...
