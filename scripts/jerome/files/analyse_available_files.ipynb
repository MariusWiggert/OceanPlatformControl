# %%
# %load_ext autoreload
# %autoreload 2
# %cd '/Users/jeromejeannin/Library/CloudStorage/GoogleDrive-jeromemjeannin@gmail.com/My Drive/Master Thesis/OceanPlatformControl'
# %pwd

from ocean_navigation_simulator.environment.ArenaFactory import ArenaFactory

ArenaFactory.analyze_files('HYCOM', 'hindcast', 'GOM')
ArenaFactory.analyze_files('Copernicus', 'forecast', 'GOM')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# /Users/jeromejeannin/Library/CloudStorage/GoogleDrive-jeromemjeannin@gmail.com/My Drive/Master Thesis/OceanPlatformControl
# Missing Files after: GOMu0.04-expt_90.1m000-2022-2022-03-07T00:00:00Z-2022-03-07T23:00:00Z.nc delta: 48.0h
# Missing Files after: GOMu0.04-expt_90.1m000-2022-2022-03-31T00:00:00Z-2022-03-31T11:00:00Z.nc delta: 0.0h
# Missing Files after: ALL-DATA-YEARS-2022-04-03T00:00:00Z-2022-04-03T23:00:00Z.nc delta: 0.0h
# Missing Files after: GOMu0.04-expt_90.1m000-2022-2022-08-29T00:00:00Z-2022-08-29T23:00:00Z.nc delta: 72.0h
# Missing Files after: GOMu0.04-expt_90.1m000-2022-2022-10-19T00:00:00Z-2022-10-19T23:00:00Z.nc delta: 48.0h
# Missing Files after: cmems_mod_glo_phy_anfc_merged-uv_PT1H-i-2022-04-19T12:30:00Z-2022-04-19T12:30:00Z-2022-04-28T23:30:00Z.nc delta: 48.0h
# ...

# %%
# %load_ext autoreload
# %autoreload 2
# %cd '/Users/jeromejeannin/Library/CloudStorage/GoogleDrive-jeromemjeannin@gmail.com/My Drive/Master Thesis/OceanPlatformControl'
# %pwd

from ocean_navigation_simulator.environment.ArenaFactory import ArenaFactory

# analyze_files('HYCOM', 'forecast', 'GOM')
# ArenaFactory.analyze_files("Copernicus", "forecast", "Region 1", True)
ArenaFactory.analyze_files("HYCOM", "hindcast", "Region 1", True)
# analyze_files('Copernicus', 'hindcast', 'GOM')

# analyze_files('copernicus', 'forecast', 'Region 1')
